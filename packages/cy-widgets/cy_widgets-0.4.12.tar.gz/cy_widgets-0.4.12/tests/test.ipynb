# %%
from cy_widgets.strategy.exchange.bolling import *
from cy_widgets.backtest.helper import StrategyHelper
StrategyHelper.format_identifier(BollingExchangeStrategy(**{'n': 400, 'm':2, 'open_deviate_threshold': 0.01}))
# BollingExchangeStrategy(**{'n': 400, 'm':2, 'open_deviate_threshold': 0.01}).identifier
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-f281796f80b7> in <module>
#       1 from cy_widgets.strategy.exchange.bolling import *
#       2 from cy_widgets.backtest.helper import StrategyHelper
# ----> 3 StrategyHelper.format_identifier(BollingExchangeStrategy(**{'n': 400, 'm':2, 'open_deviate_threshold': 0.01}))
#       4 # BollingExchangeStrategy(**{'n': 400, 'm':2, 'open_deviate_threshold': 0.01}).identifier
#
# AttributeError: type object 'StrategyHelper' has no attribute 'format_identifier'

# %%
from cy_data_access.connection.connect import *
from cy_data_access.models.quant import *
from cy_data_access.models.log import *
from cy_widgets.strategy.neutral import *
from cy_procedure.subject.neutral.proc.binance_swap_neutral import *

connect_db_env(db_name=DB_QUANT)
connect_db_env(db_name=DB_CONFIG)
connect_db_env(db_name=DB_MARKET)
connect_db_env(db_name=DB_POSITION)
connect_db_env(db_name=DB_LOG)
bc_cfg = BrickCarrierCfg.objects.get({'_id': 3})

neu = BinanceSwapNeutral(bc_cfg, '', LogType.BINANCE_NEUTRAL, True)
neu.perform_proc()
# Out:
# **BinanceNeutralStrategy_1**
#
# **前次持仓**:
# VETUSDT: -1082.0
# OMGUSDT: 9.2
# DEFIUSDT: 0.029
# STORJUSDT: 85.0
# BLZUSDT: -211.0
# RENUSDT: 98.0
# NEARUSDT: -28.0
# LRCUSDT: -77.0
#
# 下次执行时间: 2021-01-20 15:00:00
# trade_usdt_old： 50 trade_usdt_new： 50
#
# **账户净值**: 50 USDT
#
#      key  策略分配资金_旧  策略分配资金_新
# 0  3h_0H  4.166667  4.166667
# 1  3h_1H  4.166667  4.166667
# 2  3h_2H  4.166667  4.166667
# BTC/USDT 没有最近的K线, 144000.0
# XMR/USDT 没有最近的K线, 144000.0
# DASH/USDT 没有最近的K线, 144000.0
# ETH/USDT 没有最近的K线, 144000.0
# BCH/USDT 没有最近的K线, 144000.0
# ZEC/USDT 没有最近的K线, 144000.0
# XRP/USDT 没有最近的K线, 144000.0
# XTZ/USDT 没有最近的K线, 144000.0
# EOS/USDT 没有最近的K线, 144000.0
# BNB/USDT 没有最近的K线, 144000.0
# LTC/USDT 没有最近的K线, 144000.0
# ATOM/USDT 没有最近的K线, 144000.0
# TRX/USDT 没有最近的K线, 144000.0
# ONT/USDT 没有最近的K线, 144000.0
# ETC/USDT 没有最近的K线, 144000.0
# IOTA/USDT 没有最近的K线, 144000.0
# LINK/USDT 没有最近的K线, 144000.0
# BAT/USDT 没有最近的K线, 144000.0
# XLM/USDT 没有最近的K线, 144000.0
# VET/USDT 没有最近的K线, 144000.0
# ADA/USDT 没有最近的K线, 144000.0
# NEO/USDT 没有最近的K线, 144000.0
# QTUM/USDT 没有最近的K线, 144000.0
# KAVA/USDT 没有最近的K线, 144000.0
# BAND/USDT 没有最近的K线, 144000.0
# IOST/USDT 没有最近的K线, 144000.0
# THETA/USDT 没有最近的K线, 144000.0
# RLC/USDT 没有最近的K线, 144000.0
# ALGO/USDT 没有最近的K线, 144000.0
# WAVES/USDT 没有最近的K线, 144000.0
# ZIL/USDT 没有最近的K线, 144000.0
# MKR/USDT 没有最近的K线, 144000.0
# KNC/USDT 没有最近的K线, 144000.0
# SNX/USDT 没有最近的K线, 144000.0
# ZRX/USDT 没有最近的K线, 144000.0
# DOT/USDT 没有最近的K线, 144000.0
# COMP/USDT 没有最近的K线, 144000.0
# DEFI/USDT 没有最近的K线, 144000.0
# OMG/USDT 没有最近的K线, 144000.0
# YFI/USDT 没有最近的K线, 144000.0
# DOGE/USDT 没有最近的K线, 144000.0
# BAL/USDT 没有最近的K线, 144000.0
# SXP/USDT 没有最近的K线, 144000.0
# CRV/USDT 没有最近的K线, 144000.0
# TRB/USDT 没有最近的K线, 144000.0
# YFII/USDT 没有最近的K线, 144000.0
# UNI/USDT 没有最近的K线, 144000.0
# RUNE/USDT 没有最近的K线, 144000.0
# AVAX/USDT 没有最近的K线, 144000.0
# FTM/USDT 没有最近的K线, 144000.0
# SUSHI/USDT 没有最近的K线, 144000.0
# HNT/USDT 没有最近的K线, 144000.0
# SRM/USDT 没有最近的K线, 144000.0
# BZRX/USDT 没有最近的K线, 144000.0
# ENJ/USDT 没有最近的K线, 144000.0
# EGLD/USDT 没有最近的K线, 144000.0
# FLM/USDT 没有最近的K线, 144000.0
# SOL/USDT 没有最近的K线, 144000.0
# TOMO/USDT 没有最近的K线, 144000.0
# REN/USDT 没有最近的K线, 144000.0
# ICX/USDT 没有最近的K线, 144000.0
# STORJ/USDT 没有最近的K线, 144000.0
# KSM/USDT 没有最近的K线, 144000.0
# BLZ/USDT 没有最近的K线, 144000.0
# NEAR/USDT 没有最近的K线, 144000.0
# FIL/USDT 没有最近的K线, 144000.0
# AAVE/USDT 没有最近的K线, 144000.0
# RSR/USDT 没有最近的K线, 144000.0
# SKL/USDT 没有最近的K线, 144000.0
# LRC/USDT 没有最近的K线, 144000.0
# GRT/USDT 没有最近的K线, 144000.0
# MATIC/USDT 没有最近的K线, 144000.0
# 1INCH/USDT 没有最近的K线, 144000.0
# OCEAN/USDT 没有最近的K线, 144000.0
# AKRO/USDT 数据太少
# DOTECO/USDT 数据太少
# CVC/USDT 没有最近的K线, 144000.0
# BEL/USDT 没有最近的K线, 144000.0
# CTK/USDT 没有最近的K线, 144000.0
# AXS/USDT 没有最近的K线, 144000.0
# ALPHA/USDT 没有最近的K线, 144000.0
# ZEN/USDT 没有最近的K线, 144000.0
# 获取所有币种K线数据完成，花费时间： 4.445311069488525 0
# 可选的币太少了，0
#
# **BinanceNeutralStrategy_1**
#
# **前次持仓**:
# VETUSDT: -1082.0
# OMGUSDT: 9.2
# DEFIUSDT: 0.029
# STORJUSDT: 85.0
# BLZUSDT: -211.0
# RENUSDT: 98.0
# NEARUSDT: -28.0
# LRCUSDT: -77.0
#
# 下次执行时间: 2021-01-20 15:00:00
